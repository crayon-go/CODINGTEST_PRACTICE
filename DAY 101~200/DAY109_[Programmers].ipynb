# %%
1 1
2 2
3 4
4 5
5 7
6 8
7 10
8 11
9 14
10 16
11 17
12 18
13 20
14 22
15 25

# %%
n = 15
# 25

# %%
n = 40
# 76

# %%
cnt = 0
answer = 0

while True:
    print("--------")
    answer += 1
    print(answer, cnt)  # 25, 15
    if answer % 3 == 0:
        print("if")
        pass
    elif "3" in str(answer):
        print('elif')
        pass
    else:
        print("else")
        cnt += 1
    
    if cnt == n:
        break
# Out:
# --------
# 1 0
# else
# --------
# 2 1
# else
# --------
# 3 2
# if
# --------
# 4 2
# else
# --------
# 5 3
# else
# --------
# 6 4
# if
# --------
# 7 4
# else
# --------
# 8 5
# else
# --------
# 9 6
# if
# --------
# 10 6
# else
# --------
# 11 7
# else
# --------
# 12 8
# if
# --------
# 13 8
# elif
# --------
# 14 8
# else
# --------
# 15 9
# if
# --------
# 16 9
# else
# --------
# 17 10
# else
# --------
# 18 11
# if
# --------
# 19 11
# else
# --------
# 20 12
# else
# --------
# 21 13
# if
# --------
# 22 13
# else
# --------
# 23 14
# elif
# --------
# 24 14
# if
# --------
# 25 14
# else
# --------
# 26 15
# else
# --------
# 27 16
# if
# --------
# 28 16
# else
# --------
# 29 17
# else
# --------
# 30 18
# if
# --------
# 31 18
# elif
# --------
# 32 18
# elif
# --------
# 33 18
# if
# --------
# 34 18
# elif
# --------
# 35 18
# elif
# --------
# 36 18
# if
# --------
# 37 18
# elif
# --------
# 38 18
# elif
# --------
# 39 18
# if
# --------
# 40 18
# else
# --------
# ...

# %%
answer, cnt
# Out:
# (76, 40)

# %%
n = 15  # 25

answer = 0
for _ in range(n):
    answer += 1
    while answer % 3 == 0 or '3' in str(answer):
        answer += 1
answer
# Out:
# 25
