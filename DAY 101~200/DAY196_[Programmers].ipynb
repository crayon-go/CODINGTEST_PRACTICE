# %%
import re

def gender_features(word):
    return {'last_letter': re.sub('[0-9]', '', word)[-1].lower()}

# %%
gender_features("wnsdh21")
# Out:
# {'last_letter': 'h'}

# %%
labeled_names = ([(name, 'male') for name in open('male.txt').read().split('\n')] + 
                 [(name, 'female') for name in open('female.txt').read().split('\n')])

# %%
import random
random.shuffle(labeled_names)

# %%
labeled_names
# Out:
# [('Orton', 'female'),
#  ('Henry', 'male'),
#  ('Domenic', 'female'),
#  ('Herrmann', 'male'),
#  ('Yanaton', 'female'),
#  ('Bobbie', 'female'),
#  ('Thornie', 'male'),
#  ('Clair', 'male'),
#  ('Abe', 'male'),
#  ('Reinhold', 'female'),
#  ('Raoul', 'female'),
#  ('Apollo', 'female'),
#  ('Wittie', 'male'),
#  ('Hamil', 'male'),
#  ('Jess', 'male'),
#  ('Caspar', 'female'),
#  ('Mikael', 'male'),
#  ('Pieter', 'male'),
#  ('Renard', 'male'),
#  ('Lucas', 'male'),
#  ('Gershon', 'male'),
#  ('Andrzej', 'male'),
#  ('Talbot', 'male'),
#  ('Matthaeus', 'female'),
#  ('Alfonzo', 'female'),
#  ('Chris', 'male'),
#  ('Ashton', 'male'),
#  ('Garold', 'male'),
#  ('Harold', 'female'),
#  ('Curtis', 'female'),
#  ('Abbie', 'male'),
#  ('Alfredo', 'male'),
#  ('Bartie', 'male'),
#  ('Sterne', 'female'),
#  ('Welby', 'female'),
#  ('Alaa', 'female'),
#  ('Sven', 'male'),
#  ('Waylon', 'male'),
#  ('Eli', 'female'),
#  ('Kalle', 'male'),
#  ('Ansel', 'female'),
#  ('Odie', 'female'),
# ...

# %%
len(labeled_names)
# Out:
# 5886

# %%
import nltk

featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]

classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
len(train_set)
# Out:
# 5386

# %%
len(test_set)
# Out:
# 500

# %%
featuresets
# Out:
# [({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'c'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'n'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'd'}, 'female'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'r'}, 'female'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'j'}, 'male'),
#  ({'last_letter': 't'}, 'male'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'd'}, 'male'),
# ...

# %%
featuresets[0]
# Out:
# ({'last_letter': 'n'}, 'female')

# %%
classifier.classify(gender_features('wnsdh21'))
# Out:
# 'female'

# %%
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.438

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#              last_letter = 'j'            female : male   =      1.4 : 1.0
#              last_letter = 'w'            female : male   =      1.4 : 1.0
#              last_letter = 'b'            female : male   =      1.2 : 1.0
#              last_letter = 'v'            female : male   =      1.1 : 1.0
#              last_letter = 'c'              male : female =      1.1 : 1.0
#              last_letter = 'z'            female : male   =      1.1 : 1.0
#              last_letter = 'u'              male : female =      1.1 : 1.0
#              last_letter = 'a'              male : female =      1.1 : 1.0
#              last_letter = 'm'              male : female =      1.1 : 1.0
#              last_letter = 'p'            female : male   =      1.1 : 1.0
